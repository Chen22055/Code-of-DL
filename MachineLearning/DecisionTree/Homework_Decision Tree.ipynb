# %% [markdown]
# <center>
#     <h1><font color=darkred> Tsinghua University </font></h1>
#     <h1><font color=darkred> Department of Industrial Engineering </font></h1>
#     <h3> Machine Learning and Big-data (30160253) </h3>
#     <h4> Fall 2025 </h4>
#     <hr>
#     <h1> Homework 4: Decision Tree </h1>
#     <h3></h3>
# </center>

# %% [markdown]
# ### 1. Problem
#
# 1) Using decision trees to classify the Iris dataset.
#
# 2) Calculate the accuracy and F1 score to evaluate the performance of the model.
#
# 3) Draw the decision tree generated by the model. Draw the confusion matrix to visualize the classification results on the test set.

# %% [markdown]
# ### 2. Data processing
#
# 1) Load the Iris dataset.
#
# 2) Print feature names, and class names of the target variable.
#
# 3) Split the training set and the test set.

# %%
# load packages
import numpy as np
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()
X = iris.data
y = iris.target

# Display feature names
print("features::", iris.feature_names)
 
# Display labels (The class of the target variable)
print("labels:", iris.target_names)
# Out:
# features:: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# labels: ['setosa' 'versicolor' 'virginica']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.4)

# %% [markdown]
# ### 3. Decision Tree classifier

# %%
clf = tree.DecisionTreeClassifier(random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %% [markdown]
# ### 4. Permance metrics

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='micro')

print("Accuracy:", accuracy)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.95
# F1 Score: 0.95

# %% [markdown]
# ### 4. Visualization
# 1) Draw the decision tree generated by the model.
#
# 2) Draw the confusion matrix to visualize the classification results on the test set.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib as mpl

mpl.rcParams["font.size"] = 24

# Confusion Matrix
fig, ax = plt.subplots(figsize=(8, 8))
disp = ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test, 
                                             display_labels = clf.classes_, ax=ax, cmap = 'Blues')

# %%
#Plot the Decision Tree
fig, ax = plt.subplots(figsize=(18, 22))
disp = tree.plot_tree(clf,feature_names = iris.feature_names, class_names=iris.target_names, filled=True, ax=ax,
                      proportion = True)
plt.show()
